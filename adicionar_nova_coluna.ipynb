# %% [markdown]
# <img  align="left"  width="93" height="95" src="resources/img1.jpeg">

# %% [markdown]
# # Como adicionar uma nova coluna a um dataframe do Pandas?

# %% [markdown]
# **Motivações:**
#
# 1. Construir uma nova coluna a partir de outra(s);
# 2. Construir uma nova coluna;
# 3. A partir de dados existentes anexar a um dataframe.

# %% [markdown]
# ---

# %% [markdown]
# ## Let's Code!

# %% [markdown]
# **Descrição Conjunto de Dados:**
#
# O conjunto de dados (*dataset*) contém informações sobre carros usados.
#
# **Colunas:**
#
# |Nome coluna| Descrição|
# |-|-|
# |nome| Nome do carro|
# |ano|Ano do carro|
# |preço_venda|Preço de venda ($)|
# |quilometragem|Quilometragem|
# |tipo_combustivel|Tipo de combustível usado|
# |tipo_vendedor|Tipo de vendedor|
# |tipo_transmissao|Tipo de transmissão do veículo|
# |dono|Dono (primeiro, segundo, etc.) |
#
# **Referência:**
#
# Os dados podem ser baixados em [link](https://www.kaggle.com/nehalbirla/vehicle-dataset-from-cardekho).

# %%
import pandas as pd

df_raw = pd.read_csv('data/dataset_colunas_traduzidas.csv', sep=',')

serie_donos = df_raw['dono'].copy()
df = df_raw.drop(columns='dono')

# %%
# inspeciona as n primeiras linhas
df.head()
# Out:
#                        nome   ano  preço_venda  quilometragem  \
# 0             Maruti 800 AC  2007        60000          70000
# 1  Maruti Wagon R LXI Minor  2007       135000          50000
# 2      Hyundai Verna 1.6 SX  2012       600000         100000
# 3    Datsun RediGO T Option  2017       250000          46000
# 4     Honda Amaze VX i-DTEC  2014       450000         141000
#
#   tipo_combustivel tipo_vendedor tipo_transmissao
# 0           Petrol    Individual           Manual
# 1           Petrol    Individual           Manual
# 2           Diesel    Individual           Manual
# 3           Petrol    Individual           Manual
# 4           Diesel    Individual           Manual

# %%
# inspeciona a série destacada
serie_donos
# Out:
# 0        First Owner
# 1        First Owner
# 2        First Owner
# 3        First Owner
# 4       Second Owner
#             ...
# 4335    Second Owner
# 4336    Second Owner
# 4337    Second Owner
# 4338     First Owner
# 4339     First Owner
# Name: dono, Length: 4340, dtype: object

# %% [markdown]
# ### Método 1

# %% [markdown]
# [Documentação](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.assign.html)

# %%
# uso do método .assign()
df.assign(donos=serie_donos)
# Out:
#                                      nome   ano  preço_venda  quilometragem  \
# 0                           Maruti 800 AC  2007        60000          70000
# 1                Maruti Wagon R LXI Minor  2007       135000          50000
# 2                    Hyundai Verna 1.6 SX  2012       600000         100000
# 3                  Datsun RediGO T Option  2017       250000          46000
# 4                   Honda Amaze VX i-DTEC  2014       450000         141000
# ...                                   ...   ...          ...            ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014       409999          80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014       409999          80000
# 4337                  Maruti 800 AC BSIII  2009       110000          83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016       865000          90000
# 4339                     Renault KWID RXT  2016       225000          40000
#
#      tipo_combustivel tipo_vendedor tipo_transmissao         donos
# 0              Petrol    Individual           Manual   First Owner
# 1              Petrol    Individual           Manual   First Owner
# 2              Diesel    Individual           Manual   First Owner
# 3              Petrol    Individual           Manual   First Owner
# 4              Diesel    Individual           Manual  Second Owner
# ...               ...           ...              ...           ...
# 4335           Diesel    Individual           Manual  Second Owner
# 4336           Diesel    Individual           Manual  Second Owner
# 4337           Petrol    Individual           Manual  Second Owner
# 4338           Diesel    Individual           Manual   First Owner
# 4339           Petrol    Individual           Manual   First Owner
#
# [4340 rows x 8 columns]

# %%
df.head(3)
# Out:
#                        nome   ano  preço_venda  quilometragem  \
# 0             Maruti 800 AC  2007        60000          70000
# 1  Maruti Wagon R LXI Minor  2007       135000          50000
# 2      Hyundai Verna 1.6 SX  2012       600000         100000
#
#   tipo_combustivel tipo_vendedor tipo_transmissao
# 0           Petrol    Individual           Manual
# 1           Petrol    Individual           Manual
# 2           Diesel    Individual           Manual

# %% [markdown]
# ### Método 2 - a

# %%
# atribui valor constante a uma nova coluna
df['eh_carro'] = 'Sim'

# %%
df.head(3)
# Out:
#                        nome   ano  preço_venda  quilometragem  \
# 0             Maruti 800 AC  2007        60000          70000
# 1  Maruti Wagon R LXI Minor  2007       135000          50000
# 2      Hyundai Verna 1.6 SX  2012       600000         100000
#
#   tipo_combustivel tipo_vendedor tipo_transmissao eh_carro
# 0           Petrol    Individual           Manual      Sim
# 1           Petrol    Individual           Manual      Sim
# 2           Diesel    Individual           Manual      Sim

# %% [markdown]
# ### Método 2 - b

# %%
# Constrói nova coluna com base em operações sobre colunas já existentes 
df['valor_por_km'] = df['preço_venda']/ df['quilometragem']

# %%
df.head()
# Out:
#                        nome   ano  preço_venda  quilometragem  \
# 0             Maruti 800 AC  2007        60000          70000
# 1  Maruti Wagon R LXI Minor  2007       135000          50000
# 2      Hyundai Verna 1.6 SX  2012       600000         100000
# 3    Datsun RediGO T Option  2017       250000          46000
# 4     Honda Amaze VX i-DTEC  2014       450000         141000
#
#   tipo_combustivel tipo_vendedor tipo_transmissao eh_carro  valor_por_km
# 0           Petrol    Individual           Manual      Sim      0.857143
# 1           Petrol    Individual           Manual      Sim      2.700000
# 2           Diesel    Individual           Manual      Sim      6.000000
# 3           Petrol    Individual           Manual      Sim      5.434783
# 4           Diesel    Individual           Manual      Sim      3.191489

# %% [markdown]
# ### Método 3

# %% [markdown]
# [Documentação](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html?highlight=loc#pandas.DataFrame.loc)

# %%
# atribui um valor a partir de condições com uso da propriedade .loc[]
df.loc[df['ano'] > 2010, 'novos'] = True

# %%
# amostra n linhas
df.sample(10)
# Out:
#                                            nome   ano  preço_venda  \
# 1875                   Tata Indica Vista TDI LX  2013       185000
# 2839                      Maruti Alto LXi BSIII  2008       130000
# 1893                         Maruti Wagon R VXI  2005       100000
# 1803                        Tata New Safari 4X4  2007       199000
# 3179                             Tata Indigo LS  2010       160000
# 3798  Tata Indica Vista Aura Plus 1.3 Quadrajet  2012       200000
# 2816                    Mahindra Scorpio S4 4WD  2015       600000
# 3833                   Mahindra TUV 300 T4 Plus  2017       650000
# 2587          Tata Tigor 1.2 Revotron XZ Option  2019       670000
# 3451                     Maruti SX4 ZXI MT BSIV  2011       150000
#
#       quilometragem tipo_combustivel tipo_vendedor tipo_transmissao eh_carro  \
# 1875          65000           Diesel    Individual           Manual      Sim
# 2839          40000           Petrol    Individual           Manual      Sim
# 1893         100000           Petrol    Individual           Manual      Sim
# 1803          78771           Diesel        Dealer           Manual      Sim
# 3179         102000           Diesel    Individual           Manual      Sim
# 3798          90000           Diesel    Individual           Manual      Sim
# 2816          60000           Diesel    Individual           Manual      Sim
# 3833          60000           Diesel    Individual           Manual      Sim
# 2587          17000           Petrol    Individual           Manual      Sim
# 3451         160000           Petrol    Individual           Manual      Sim
#
#       valor_por_km novos
# 1875      2.846154  True
# 2839      3.250000   NaN
# 1893      1.000000   NaN
# 1803      2.526310   NaN
# 3179      1.568627   NaN
# 3798      2.222222  True
# 2816     10.000000  True
# 3833     10.833333  True
# 2587     39.411765  True
# 3451      0.937500  True
